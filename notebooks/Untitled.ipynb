# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# path to dataset
image_dir = '../data/images/'
annotations_file = '../data/captions.txt'

# %%
# loading captions from .txt
captions = []
with open(annotations_file, 'r') as file:
    for line in file:
        image, caption = line.strip().split(",", 1) # split on the first comma
        captions.append({'image': image.strip(), 'caption': caption.strip()})

# convert to a dataframe
captions_df = pd.DataFrame(captions)
captions_df.head()
# Out:
#                        image  \
# 0                      image
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0                                            caption
# 1  A child in a pink dress is climbing up a set o...
# 2              A girl going into a wooden building .
# 3   A little girl climbing into a wooden playhouse .
# 4  A little girl climbing the stairs to her playh...

# %%
# displaying an image with a caption
sample_image = os.path.join(image_dir, captions_df.iloc[60]['image'])
img = Image.open(sample_image)

plt.imshow(img)
plt.title(captions_df.iloc[60]['caption'])
plt.axis('off')
plt.show()
